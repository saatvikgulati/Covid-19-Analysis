# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
from google.colab import drive
drive.mount('/content/drive/',force_remount=True)
os.chdir('/content/drive/My Drive/Colab Notebooks/')
# Out:
# Mounted at /content/drive/

# %%
#url="https://public.dm.files.1drv.com/y4mwmB7RGrSDgZl-r-P9Nr_49vxl6hfsE3GrSX7eocW5m3ub4_ioLWlFHGa4b6MPrCDdcBA8EYoeBZOzoECMLqwZZa5Ujtun7xEfOV0JiMwWfqWRYroj6iJcLX2RM3_T3LSqwJddmgDQnc3ga3WUuF6eP-k8nVo8kmIvxvShYz2WTSUbjTt7icWNOxeikpngJqEyqkS1glPmDC-PjTa4Gqv0boSGQrkJ8DF45XCapZx42c?access_token=EwAwA61DBAAUzl/nWKUlBg14ZGcybuC4/OHFdfEAATwqZg%2b%2bhpSAwekvdzSS%2bSOn/7iklziV1Llgw2aJxUDe20oq2EodGPvz%2bfJQkngoaBioMg%2bRal8KlFv8MUvQYkKCJS1ZSsUfHkRyDVRat0w6BPWal9TknE/b8fVnHCxmrpRe9JfsSmztHsQxM/Vu8K7KE347wNaAq7vV6MNC5fJ7x/wA1AsvSzF7smWYGjtHyYTQXfn5cP4BcQpDJU7r6wV4rYgeD5avQORETWVb34wniBLzlv9jLUaMMwdq98lzGCVKSgRCxWwoCkH7wLnLDdkfVc88Y1XEwY43WRsQIF1KwfOs1Q0bAgV%2bsK1SlqDynHBlqbLMjvVEHPOrdV%2bhsGQDZgAACNzD7Nr3tsazAAJn98SS/RymH9A%2bF6dHmmNOsPnqlZ7lWYXy1hMzDLyoTSWGjawyvYe5TeaNqqrGhBcdyPEFcPNP3CU46eaillksTpv/lVM9XsvmLWXZatquxHZ0YqBwSGCx76qRg/lAhOrrs4MdFycTLFTxDvGY8klaIkww/%2bL0fonhic1iCCpfUarrSpZjxyZDd2vtIgFFWfX9Lrru0UTFybqoi2UPMDCpc/Us9spGBn3grkn6xIlW7ZMvaPQsh0jgoxwrhBca/qsIR7ULpj6RwWVog5EhYCpypeFGbE7xvo1OghZEYWBS%2b2bgqtYYJZyeYjnUplq/e65DSqOH3c5uH78Dohwfyv9Wx9pzWJCmkIThqlqsVaEAGZyJV5sCD5yP4r%2biAdZTp5EMmKaSFFV6JKp/re30ASuECu3peSPlp3eUHjzf9Rqpki/X4xGE5AHOuk3IDoHD0A2oJGpkCbR1qoxH6JyYVJ8l0sKxCnqBpMTVu79tMnURZeGJxiZ8O56mXnMrhWRVik4c/Ak1D0FhcPLZN5r0eqWFyer%2bBgczmH0g5XjreIg257yumdwr1DUbggCEIi/mpda7J5zDYGSpEuwonIpMMjiVHhzacx8zBHmDfGcZ0MZHRvhgqNoToE2UOLkzQ%2b2XqQq2Wr5Wrm0GUhWK5UpD5K%2bH8YbxMUaiMV9RTMZoxQSC1yUC"
url="Data-2.xlsx"
covid=pd.read_excel(url,header=0)
#covid[covid['total_cases_per_million']==covid['total_cases_per_million'].max()]
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17215 entries, 0 to 17214
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   iso_code                  17151 non-null  object
#  1   location                  17215 non-null  object
#  2   date                      17215 non-null  object
#  3   total_cases               17215 non-null  int64
#  4   new_cases                 17215 non-null  int64
#  5   total_deaths              17215 non-null  int64
#  6   new_deaths                17215 non-null  int64
#  7   total_cases_per_million   16909 non-null  float64
#  8   new_cases_per_million     16909 non-null  float64
#  9   total_deaths_per_million  16909 non-null  float64
#  10  new_deaths_per_million    16909 non-null  float64
#  11  total_tests               4455 non-null   float64
#  12  new_tests                 3961 non-null   float64
# ...

# %%
covid['date']=pd.to_datetime(covid['date'])
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17215 entries, 0 to 17214
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   iso_code                  17151 non-null  object
#  1   location                  17215 non-null  object
#  2   date                      17215 non-null  datetime64[ns]
#  3   total_cases               17215 non-null  int64
#  4   new_cases                 17215 non-null  int64
#  5   total_deaths              17215 non-null  int64
#  6   new_deaths                17215 non-null  int64
#  7   total_cases_per_million   16909 non-null  float64
#  8   new_cases_per_million     16909 non-null  float64
#  9   total_deaths_per_million  16909 non-null  float64
#  10  new_deaths_per_million    16909 non-null  float64
#  11  total_tests               4455 non-null   float64
#  12  new_tests                 3961 non-null   float64
# ...

# %%
covid.index
# Out:
# RangeIndex(start=0, stop=17215, step=1)

# %%
covid.set_index('date')['total_deaths_per_million'].plot()

# %%
sns.set(font_scale=1.4)
covid.set_index('date')['total_deaths_per_million'].plot(figsize=(12, 10), linewidth=2.5, color='maroon')
plt.xlabel("Date", labelpad=15)
plt.ylabel("No of Deaths per million", labelpad=15)
plt.title("No of covid deaths", y=1.02, fontsize=22);
